# %% [markdown]
# # Linear Probe Analysis
#
# Compare test accuracy: random init vs MAE pretrained at 75% / 90% / 95% masking. Run linear probe from CLI first, then aggregate results here.

# %%
import matplotlib.pyplot as plt

# Fill after running: python -m src.main linear_probe --config configs/mask75.yaml --checkpoint ...
results = {
    "random": 0.0,   # baseline without pretraining
    "mask75": 0.0,
    "mask90": 0.0,
    "mask95": 0.0,
}
plt.bar(results.keys(), results.values())
plt.ylabel("Test accuracy")
plt.title("Linear probe on 47 DTD classes")
plt.tight_layout()
plt.show()
